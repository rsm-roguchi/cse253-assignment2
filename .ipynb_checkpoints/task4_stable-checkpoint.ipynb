# %%
from stable_audio_tools.models.pretrained import get_pretrained_model
import torch

model, model_config = get_pretrained_model("stabilityai/stable-audio-open-small")
# Out:
# No module named 'flash_attn'
# flash_attn not installed, disabling Flash Attention
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
import sys
sys.path.append("/workspace/stable-audio-tools")

# %%
# !pwd
# Out:
# /workspace

# %%
from pathlib import Path

AUDIO_DIR = Path("/workspace/data4")
OUTPUT_DIR = Path("/workspace/data4_preencoded_overlap")
SAMPLE_RATE = 44100
SEGMENT_DURATION = 8.0  # seconds
SEGMENT_SAMPLES = int(SAMPLE_RATE * SEGMENT_DURATION)
MIN_RMS_THRESHOLD = 0.01
OVERLAP_RATIO = 0.5
STEP_SIZE = int(SEGMENT_SAMPLES * (1 - OVERLAP_RATIO))

# %%
import torchaudio
import numpy as np
import torch
import json
from pathlib import Path

torch.set_float32_matmul_precision('high')

# === CONFIG ===
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# === MODEL CHECK ===
assert hasattr(model, "pretransform") and model.pretransform is not None, \
    "❌ Model must have a `.pretransform` encoder"

model.pretransform.to("cuda").eval()

def is_non_silent(segment, threshold=MIN_RMS_THRESHOLD):
    rms = segment.pow(2).mean().sqrt().item()
    return rms > threshold

print("🔁 Encoding and saving latent segments + metadata...")

total_saved = 0

for file in AUDIO_DIR.glob("*.wav"):
    try:
        audio, sr = torchaudio.load(file)
        if audio.numel() == 0:
            print(f"⚠️ Empty audio in {file.name}, skipping.")
            continue

        if sr != SAMPLE_RATE:
            audio = torchaudio.transforms.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)(audio)

        if audio.shape[0] == 1:
            audio = audio.repeat(2, 1)  # [2, T]

        # Normalize
        peak = audio.abs().max()
        if peak > 0:
            audio = audio / peak

        audio_len = audio.shape[1]
        seg_idx = 0

        for start in range(0, audio_len - SEGMENT_SAMPLES + 1, STEP_SIZE):
            end = start + SEGMENT_SAMPLES
            segment = audio[:, start:end]

            if not is_non_silent(segment):
                continue

            segment = segment.unsqueeze(0).to("cuda")  # [1, 2, T]

            with torch.no_grad():
                latent = model.pretransform.encode(segment)  # [1, D, T']
                latent = latent.squeeze(0).cpu().numpy()     # [D, T']

            # === Save latent ===
            out_name = f"{file.stem}_ov{seg_idx:03d}"
            npy_path = OUTPUT_DIR / f"{out_name}.npy"
            np.save(npy_path, latent)

            # === Save metadata ===
            stem_lower = file.stem.lower()
            if "yb" in stem_lower:
                prompt = "NBA YoungBoy type aggressive trap beat"
            elif "baby" in stem_lower:
                prompt = "Lil Baby style melodic trap beat"
            else:
                prompt = "trap remix"

            padding_mask = [1] * latent.shape[-1]
            metadata = {
                "prompt": prompt,
                "seconds_total": SEGMENT_DURATION,
                "padding_mask": padding_mask
            }

            json_path = OUTPUT_DIR / f"{out_name}.json"
            with open(json_path, "w") as f:
                json.dump(metadata, f, indent=2)

            print(f"✅ Saved: {out_name}.npy + .json")
            seg_idx += 1
            total_saved += 1

    except Exception as e:
        print(f"❌ Error processing {file.name}: {e}")

print(f"🏁 Done. Saved {total_saved} valid latent segments + metadata to: {OUTPUT_DIR}")
# Out:
# 🔁 Encoding and saving latent segments + metadata...
# ✅ Saved: baby2_ov000.npy + .json
# ✅ Saved: baby2_ov001.npy + .json
# ✅ Saved: baby2_ov002.npy + .json
# ✅ Saved: baby2_ov003.npy + .json
# ✅ Saved: baby2_ov004.npy + .json
# ✅ Saved: baby2_ov005.npy + .json
# ✅ Saved: baby2_ov006.npy + .json
# ✅ Saved: baby2_ov007.npy + .json
# ✅ Saved: baby2_ov008.npy + .json
# ✅ Saved: baby2_ov009.npy + .json
# ✅ Saved: baby2_ov010.npy + .json
# ✅ Saved: baby2_ov011.npy + .json
# ✅ Saved: baby2_ov012.npy + .json
# ✅ Saved: baby2_ov013.npy + .json
# ✅ Saved: baby2_ov014.npy + .json
# ✅ Saved: baby2_ov015.npy + .json
# ✅ Saved: baby2_ov016.npy + .json
# ✅ Saved: baby2_ov017.npy + .json
# ✅ Saved: yb3_ov000.npy + .json
# ✅ Saved: yb3_ov001.npy + .json
# ✅ Saved: yb3_ov002.npy + .json
# ✅ Saved: yb3_ov003.npy + .json
# ✅ Saved: yb3_ov004.npy + .json
# ✅ Saved: yb3_ov005.npy + .json
# ✅ Saved: yb3_ov006.npy + .json
# ✅ Saved: yb3_ov007.npy + .json
# ✅ Saved: yb3_ov008.npy + .json
# ✅ Saved: yb3_ov009.npy + .json
# ✅ Saved: yb3_ov010.npy + .json
# ✅ Saved: yb3_ov011.npy + .json
# ✅ Saved: yb3_ov012.npy + .json
# ✅ Saved: yb3_ov013.npy + .json
# ✅ Saved: yb3_ov014.npy + .json
# ✅ Saved: yb3_ov015.npy + .json
# ✅ Saved: yb3_ov016.npy + .json
# ✅ Saved: yb3_ov017.npy + .json
# ✅ Saved: yb3_ov018.npy + .json
# ✅ Saved: yb3_ov019.npy + .json
# ✅ Saved: yb3_ov020.npy + .json
# ✅ Saved: yb3_ov021.npy + .json
# ✅ Saved: yb3_ov022.npy + .json
# ✅ Saved: yb3_ov023.npy + .json
# ✅ Saved: yb3_ov024.npy + .json
# ✅ Saved: yb1_ov000.npy + .json
# ✅ Saved: yb1_ov001.npy + .json
# ✅ Saved: yb1_ov002.npy + .json
# ✅ Saved: yb1_ov003.npy + .json
# ✅ Saved: yb1_ov004.npy + .json
# ✅ Saved: yb1_ov005.npy + .json
# ✅ Saved: yb1_ov006.npy + .json
# ✅ Saved: yb1_ov007.npy + .json
# ✅ Saved: yb1_ov008.npy + .json
# ✅ Saved: yb1_ov009.npy + .json
# ✅ Saved: yb1_ov010.npy + .json
# ✅ Saved: yb1_ov011.npy + .json
# ✅ Saved: yb1_ov012.npy + .json
# ✅ Saved: yb1_ov013.npy + .json
# ✅ Saved: yb1_ov014.npy + .json
# ✅ Saved: yb1_ov015.npy + .json
# ✅ Saved: yb1_ov016.npy + .json
# ✅ Saved: yb1_ov017.npy + .json
# ✅ Saved: yb1_ov018.npy + .json
# ✅ Saved: yb1_ov019.npy + .json
# ✅ Saved: yb1_ov020.npy + .json
# ✅ Saved: yb1_ov021.npy + .json
# ✅ Saved: yb1_ov022.npy + .json
# ✅ Saved: yb1_ov023.npy + .json
# ✅ Saved: yb1_ov024.npy + .json
# ✅ Saved: yb5_ov000.npy + .json
# ✅ Saved: yb5_ov001.npy + .json
# ✅ Saved: yb5_ov002.npy + .json
# ✅ Saved: yb5_ov003.npy + .json
# ✅ Saved: yb5_ov004.npy + .json
# ✅ Saved: yb5_ov005.npy + .json
# ✅ Saved: yb5_ov006.npy + .json
# ✅ Saved: yb5_ov007.npy + .json
# ✅ Saved: yb5_ov008.npy + .json
# ✅ Saved: yb5_ov009.npy + .json
# ✅ Saved: yb5_ov010.npy + .json
# ✅ Saved: yb5_ov011.npy + .json
# ✅ Saved: yb5_ov012.npy + .json
# ✅ Saved: yb5_ov013.npy + .json
# ✅ Saved: yb5_ov014.npy + .json
# ✅ Saved: yb5_ov015.npy + .json
# ✅ Saved: yb5_ov016.npy + .json
# ✅ Saved: yb5_ov017.npy + .json
# ✅ Saved: yb2_ov000.npy + .json
# ✅ Saved: yb2_ov001.npy + .json
# ✅ Saved: yb2_ov002.npy + .json
# ✅ Saved: yb2_ov003.npy + .json
# ✅ Saved: yb2_ov004.npy + .json
# ✅ Saved: yb2_ov005.npy + .json
# ✅ Saved: yb2_ov006.npy + .json
# ✅ Saved: yb2_ov007.npy + .json
# ✅ Saved: yb2_ov008.npy + .json
# ✅ Saved: yb2_ov009.npy + .json
# ✅ Saved: yb2_ov010.npy + .json
# ✅ Saved: yb2_ov011.npy + .json
# ✅ Saved: yb2_ov012.npy + .json
# ✅ Saved: yb2_ov013.npy + .json
# ✅ Saved: yb2_ov014.npy + .json
# ✅ Saved: yb2_ov015.npy + .json
# ✅ Saved: yb2_ov016.npy + .json
# ✅ Saved: yb2_ov017.npy + .json
# ✅ Saved: yb2_ov018.npy + .json
# ✅ Saved: yb2_ov019.npy + .json
# ✅ Saved: yb2_ov020.npy + .json
# ✅ Saved: yb2_ov021.npy + .json
# ✅ Saved: yb2_ov022.npy + .json
# ✅ Saved: yb2_ov023.npy + .json
# ✅ Saved: yb2_ov024.npy + .json
# ✅ Saved: yb2_ov025.npy + .json
# ✅ Saved: baby1_ov000.npy + .json
# ✅ Saved: baby1_ov001.npy + .json
# ✅ Saved: baby1_ov002.npy + .json
# ✅ Saved: baby1_ov003.npy + .json
# ✅ Saved: baby1_ov004.npy + .json
# ✅ Saved: baby1_ov005.npy + .json
# ✅ Saved: baby1_ov006.npy + .json
# ✅ Saved: baby1_ov007.npy + .json
# ✅ Saved: baby1_ov008.npy + .json
# ✅ Saved: baby1_ov009.npy + .json
# ✅ Saved: baby1_ov010.npy + .json
# ✅ Saved: baby1_ov011.npy + .json
# ✅ Saved: baby1_ov012.npy + .json
# ✅ Saved: baby1_ov013.npy + .json
# ✅ Saved: baby1_ov014.npy + .json
# ✅ Saved: baby1_ov015.npy + .json
# ✅ Saved: baby1_ov016.npy + .json
# ✅ Saved: baby1_ov017.npy + .json
# ✅ Saved: baby1_ov018.npy + .json
# ✅ Saved: yb8_ov000.npy + .json
# ✅ Saved: yb8_ov001.npy + .json
# ✅ Saved: yb8_ov002.npy + .json
# ✅ Saved: yb8_ov003.npy + .json
# ✅ Saved: yb8_ov004.npy + .json
# ✅ Saved: yb8_ov005.npy + .json
# ✅ Saved: yb8_ov006.npy + .json
# ✅ Saved: yb8_ov007.npy + .json
# ✅ Saved: yb8_ov008.npy + .json
# ✅ Saved: yb8_ov009.npy + .json
# ✅ Saved: yb8_ov010.npy + .json
# ✅ Saved: yb8_ov011.npy + .json
# ✅ Saved: yb8_ov012.npy + .json
# ✅ Saved: yb8_ov013.npy + .json
# ✅ Saved: yb8_ov014.npy + .json
# ✅ Saved: yb8_ov015.npy + .json
# ✅ Saved: yb8_ov016.npy + .json
# ✅ Saved: yb8_ov017.npy + .json
# ✅ Saved: yb8_ov018.npy + .json
# ✅ Saved: yb8_ov019.npy + .json
# ✅ Saved: yb4_ov000.npy + .json
# ✅ Saved: yb4_ov001.npy + .json
# ✅ Saved: yb4_ov002.npy + .json
# ✅ Saved: yb4_ov003.npy + .json
# ✅ Saved: yb4_ov004.npy + .json
# ✅ Saved: yb4_ov005.npy + .json
# ✅ Saved: yb4_ov006.npy + .json
# ✅ Saved: yb4_ov007.npy + .json
# ✅ Saved: yb4_ov008.npy + .json
# ✅ Saved: yb4_ov009.npy + .json
# ✅ Saved: yb4_ov010.npy + .json
# ✅ Saved: yb4_ov011.npy + .json
# ✅ Saved: yb4_ov012.npy + .json
# ✅ Saved: yb4_ov013.npy + .json
# ✅ Saved: yb4_ov014.npy + .json
# ✅ Saved: yb4_ov015.npy + .json
# ✅ Saved: yb4_ov016.npy + .json
# ✅ Saved: yb4_ov017.npy + .json
# ✅ Saved: yb4_ov018.npy + .json
# ✅ Saved: yb4_ov019.npy + .json
# ✅ Saved: yb4_ov020.npy + .json
# ✅ Saved: yb4_ov021.npy + .json
# ✅ Saved: yb4_ov022.npy + .json
# ✅ Saved: yb4_ov023.npy + .json
# ✅ Saved: yb4_ov024.npy + .json
# ✅ Saved: yb4_ov025.npy + .json
# ✅ Saved: yb4_ov026.npy + .json
# ✅ Saved: yb4_ov027.npy + .json
# ✅ Saved: yb4_ov028.npy + .json
# ✅ Saved: yb6_ov000.npy + .json
# ✅ Saved: yb6_ov001.npy + .json
# ✅ Saved: yb6_ov002.npy + .json
# ✅ Saved: yb6_ov003.npy + .json
# ✅ Saved: yb6_ov004.npy + .json
# ✅ Saved: yb6_ov005.npy + .json
# ✅ Saved: yb6_ov006.npy + .json
# ✅ Saved: yb6_ov007.npy + .json
# ✅ Saved: yb6_ov008.npy + .json
# ✅ Saved: yb6_ov009.npy + .json
# ✅ Saved: yb6_ov010.npy + .json
# ✅ Saved: yb6_ov011.npy + .json
# ✅ Saved: yb6_ov012.npy + .json
# ✅ Saved: yb6_ov013.npy + .json
# ✅ Saved: yb6_ov014.npy + .json
# ✅ Saved: yb6_ov015.npy + .json
# ✅ Saved: yb6_ov016.npy + .json
# ✅ Saved: yb6_ov017.npy + .json
# ✅ Saved: yb7_ov000.npy + .json
# ✅ Saved: yb7_ov001.npy + .json
# ✅ Saved: yb7_ov002.npy + .json
# ✅ Saved: yb7_ov003.npy + .json
# ✅ Saved: yb7_ov004.npy + .json
# ✅ Saved: yb7_ov005.npy + .json
# ✅ Saved: yb7_ov006.npy + .json
# ✅ Saved: yb7_ov007.npy + .json
# ✅ Saved: yb7_ov008.npy + .json
# ✅ Saved: yb7_ov009.npy + .json
# ✅ Saved: yb7_ov010.npy + .json
# ✅ Saved: yb7_ov011.npy + .json
# ✅ Saved: yb7_ov012.npy + .json
# ✅ Saved: yb7_ov013.npy + .json
# ✅ Saved: yb7_ov014.npy + .json
# ✅ Saved: yb7_ov015.npy + .json
# ✅ Saved: yb7_ov016.npy + .json
# ✅ Saved: yb7_ov017.npy + .json
# ✅ Saved: yb7_ov018.npy + .json
# ✅ Saved: yb7_ov019.npy + .json
# 🏁 Done. Saved 218 valid latent segments + metadata to: /workspace/data4_preencoded_overlap

# %%
from stable_audio_tools.data.dataset import create_dataloader_from_config
import json

with open("/workspace/dataset_config.json") as f:
    dataset_config = json.load(f)

train_loader = create_dataloader_from_config(
    dataset_config,
    batch_size=1,
    sample_size=SAMPLE_RATE * SEGMENT_DURATION,
    sample_rate=44100,
    audio_channels=2,
    num_workers=8
)
# Out:
# Found 218 files

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
from stable_audio_tools.training.diffusion import DiffusionCondTrainingWrapper
import pytorch_lightning as pl
import torch

torch.set_float32_matmul_precision('high')

training_wrapper = DiffusionCondTrainingWrapper(
    model=model,
    lr=1e-4,
    pre_encoded=True
)

trainer = pl.Trainer(
    max_steps=2000,                     # <-- total steps to train
    accumulate_grad_batches=2,          # <-- simulate larger batch
    precision='16-mixed',                        # <-- mixed precision (faster)
    log_every_n_steps=600,               # <-- print loss every 10 steps
    enable_progress_bar=True,           
    enable_checkpointing=False,
    val_check_interval=None,
    strategy='auto',
    devices=1
)

trainer.fit(training_wrapper, train_dataloaders=train_loader)
training_wrapper.export_model("/workspace/stable-audio-tools/saved/final_model.pt")

with open("/workspace/stable-audio-tools/saved/final_model_config.json", "w") as f:
    json.dump(model_config, f, indent=2)
# Out:
# Using 16bit Automatic Mixed Precision (AMP)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/plugins/precision/amp.py:54: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type                             | Params
# -------------------------------------------------------------------
# 0 | diffusion     | ConditionedDiffusionModelWrapper | 497 M
# 1 | diffusion_ema | EMA                              | 340 M
# 2 | losses        | MultiLoss                        | 0
# -------------------------------------------------------------------
# 341 M     Trainable params
# 496 M     Non-trainable params
# 838 M     Total params
# 3,352.279 Total estimated model params size (MB)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:293: The number of training batches (218) is smaller than the logging interval Trainer(log_every_n_steps=600). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |                                                                             | 0/? [00:00<?, ?it/s]
# /workspace/stable-audio-tools/stable_audio_tools/models/conditioners.py:362: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(dtype=torch.float16) and torch.set_grad_enabled(self.enable_grad):
# `Trainer.fit` stopped: `max_steps=2000` reached.

# %%
#import torch
#import json
#from stable_audio_tools.models.diffusion import create_diffusion_cond_from_config

# Load saved config
#with open("/workspace/stable-audio-tools/saved/final_model_config.json") as f:
    #config = json.load(f)

# Rebuild model from config
#model = create_diffusion_cond_from_config(config)
#ckpt = torch.load("/workspace/stable-audio-tools/saved/final_model.pt", map_location="cuda")
#model.load_state_dict(ckpt["state_dict"])
#model.to("cuda").eval()
# Out:
# No module named 'flash_attn'
# flash_attn not installed, disabling Flash Attention
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ConditionedDiffusionModelWrapper(
#   (model): DiTWrapper(
#     (model): DiffusionTransformer(
#       (timestep_features): FourierFeatures()
#       (to_timestep_embed): Sequential(
#         (0): Linear(in_features=256, out_features=1024, bias=True)
#         (1): SiLU()
#         (2): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (to_cond_embed): Sequential(
#         (0): Linear(in_features=768, out_features=1024, bias=False)
#         (1): SiLU()
#         (2): Linear(in_features=1024, out_features=1024, bias=False)
#       )
#       (to_global_embed): Sequential(
#         (0): Linear(in_features=768, out_features=1024, bias=False)
#         (1): SiLU()
#         (2): Linear(in_features=1024, out_features=1024, bias=False)
#       )
#       (transformer): ContinuousTransformer(
#         (layers): ModuleList(
#           (0-15): 16 x TransformerBlock(
#             (pre_norm): LayerNorm()
#             (self_attn): Attention(
#               (to_qkv): Linear(in_features=1024, out_features=3072, bias=False)
#               (to_out): Linear(in_features=1024, out_features=1024, bias=False)
#               (q_norm): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#               (k_norm): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             )
#             (self_attn_scale): Identity()
#             (cross_attend_norm): LayerNorm()
#             (cross_attn): Attention(
#               (to_q): Linear(in_features=1024, out_features=1024, bias=False)
#               (to_kv): Linear(in_features=1024, out_features=2048, bias=False)
#               (to_out): Linear(in_features=1024, out_features=1024, bias=False)
#               (q_norm): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#               (k_norm): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             )
#             (cross_attn_scale): Identity()
#             (ff_norm): LayerNorm()
#             (ff): FeedForward(
#               (ff): Sequential(
#                 (0): GLU(
#                   (act): SiLU()
#                   (proj): Linear(in_features=1024, out_features=8192, bias=True)
#                 )
#                 (1): Identity()
#                 (2): Linear(in_features=4096, out_features=1024, bias=True)
#                 (3): Identity()
#               )
#             )
#             (ff_scale): Identity()
#           )
#         )
#         (project_in): Linear(in_features=64, out_features=1024, bias=False)
#         (project_out): Linear(in_features=1024, out_features=64, bias=False)
#         (rotary_pos_emb): RotaryEmbedding()
#       )
#       (preprocess_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,), bias=False)
#       (postprocess_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,), bias=False)
#     )
#   )
#   (conditioner): MultiConditioner(
#     (conditioners): ModuleDict(
#       (prompt): T5Conditioner(
#         (proj_out): Identity()
#       )
#       (seconds_total): NumberConditioner(
#         (proj_out): Identity()
#         (embedder): NumberEmbedder(
#           (embedding): Sequential(
#             (0): LearnedPositionalEmbedding()
#             (1): Linear(in_features=257, out_features=768, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (pretransform): AutoencoderPretransform(
#     (model): AudioAutoencoder(
#       (bottleneck): VAEBottleneck()
#       (encoder): OobleckEncoder(
#         (layers): Sequential(
#           (0): Conv1d(2, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#           (1): EncoderBlock(
#             (layers): Sequential(
#               (0): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (1): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): SnakeBeta()
#               (4): Conv1d(128, 128, kernel_size=(4,), stride=(2,), padding=(1,))
#             )
#           )
#           (2): EncoderBlock(
#             (layers): Sequential(
#               (0): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (1): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): SnakeBeta()
#               (4): Conv1d(128, 256, kernel_size=(8,), stride=(4,), padding=(2,))
#             )
#           )
#           (3): EncoderBlock(
#             (layers): Sequential(
#               (0): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (1): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): SnakeBeta()
#               (4): Conv1d(256, 512, kernel_size=(8,), stride=(4,), padding=(2,))
#             )
#           )
#           (4): EncoderBlock(
#             (layers): Sequential(
#               (0): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (1): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): SnakeBeta()
#               (4): Conv1d(512, 1024, kernel_size=(16,), stride=(8,), padding=(4,))
#             )
#           )
#           (5): EncoderBlock(
#             (layers): Sequential(
#               (0): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (1): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): SnakeBeta()
#               (4): Conv1d(1024, 2048, kernel_size=(16,), stride=(8,), padding=(4,))
#             )
#           )
#           (6): SnakeBeta()
#           (7): Conv1d(2048, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#       )
#       (decoder): OobleckDecoder(
#         (layers): Sequential(
#           (0): Conv1d(64, 2048, kernel_size=(7,), stride=(1,), padding=(3,))
#           (1): DecoderBlock(
#             (layers): Sequential(
#               (0): SnakeBeta()
#               (1): ConvTranspose1d(2048, 1024, kernel_size=(16,), stride=(8,), padding=(4,))
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (4): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#                 )
#               )
#             )
#           )
#           (2): DecoderBlock(
#             (layers): Sequential(
#               (0): SnakeBeta()
#               (1): ConvTranspose1d(1024, 512, kernel_size=(16,), stride=(8,), padding=(4,))
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (4): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                 )
#               )
#             )
#           )
#           (3): DecoderBlock(
#             (layers): Sequential(
#               (0): SnakeBeta()
#               (1): ConvTranspose1d(512, 256, kernel_size=(8,), stride=(4,), padding=(2,))
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (4): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#                 )
#               )
#             )
#           )
#           (4): DecoderBlock(
#             (layers): Sequential(
#               (0): SnakeBeta()
#               (1): ConvTranspose1d(256, 128, kernel_size=(8,), stride=(4,), padding=(2,))
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (4): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#             )
#           )
#           (5): DecoderBlock(
#             (layers): Sequential(
#               (0): SnakeBeta()
#               (1): ConvTranspose1d(128, 128, kernel_size=(4,), stride=(2,), padding=(1,))
#               (2): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (3): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#               (4): ResidualUnit(
#                 (layers): Sequential(
#                   (0): SnakeBeta()
#                   (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#                   (2): SnakeBeta()
#                   (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#                 )
#               )
#             )
#           )
#           (6): SnakeBeta()
#           (7): Conv1d(128, 2, kernel_size=(7,), stride=(1,), padding=(3,), bias=False)
#           (8): Identity()
#         )
#       )
#     )
#   )
# )

# %%
from stable_audio_tools.inference.generation import generate_diffusion_cond

conditioning = [{
    "prompt": "NBA Youngboy style trap",
    "seconds_total": 90.0
}]

negative_conditioning =[{
    'prompt': 'avoid repetition',
    'seconds_total': 90.0
}]

DURATION_SEC = sum(p["seconds_total"] for p in conditioning)  # = 90
SAMPLE_SIZE = int(SAMPLE_RATE * DURATION_SEC)  # = 3,969,000


output = generate_diffusion_cond(
    model=model.to("cuda"),       # make 100% sure model is on GPU
    steps=1024,
    cfg_scale=6.0,
    conditioning=conditioning,
    sample_size=SAMPLE_SIZE,       # 9 seconds
    device="cuda"                 # force everything onto GPU
)
# Out:
# 1410538508
# 1024it [20:26,  1.20s/it]

# %%
import torchaudio
from einops import rearrange
import torch

# Rearrange: [B, C, T] -> [C, T] for saving
waveform = rearrange(output, "b c n -> c (b n)")

# Peak normalize and convert to 16-bit PCM
waveform = waveform.to(torch.float32).div(torch.max(torch.abs(waveform))).mul(32767).clamp(-32768, 32767).to(torch.int16).cpu()

# %%
torchaudio.save("remix_output_prompt_1024_steps.wav", waveform, sample_rate=44100)
print("✅ Saved to remix_output_prompt_1024_steps.wav")
# Out:
# ✅ Saved to remix_output_prompt_1024_steps.wav

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load your audio file
audio_path = "remix_output_prompt_1024_steps.wav"
y, sr = librosa.load(audio_path, sr=44100)

# Plot waveform
plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr, alpha=0.8)
plt.title("Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.tight_layout()
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load your audio
y, sr = librosa.load("remix_output_prompt_1024_steps.wav", sr=None)

# Generate log-power Mel spectrogram
S = librosa.feature.melspectrogram(y=y, sr=44100, n_fft=2048, hop_length=512, n_mels=128)
log_S = librosa.power_to_db(S, ref=np.max)

# Plot
plt.figure(figsize=(12, 4))
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel', cmap='magma')
plt.colorbar(format='%+2.0f dB')
plt.title("Mel Spectrogram")
plt.tight_layout()
plt.show()
